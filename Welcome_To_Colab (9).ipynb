# %%
# !git clone https://github.com/DemirDorukDilek/DDoP --branch Util --single-branch git
# Out:
# Cloning into 'git'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 168 (delta 34), reused 37 (delta 16), pack-reused 100 (from 1)
# Receiving objects: 100% (168/168), 3.31 MiB | 7.17 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
# !mv git/run.py ./main.py
# !mv git/DDOP .

# %%
# !chmod +x cross_build.sh

# %%
# !./cross_build.sh  setup
# Out:
# [*] === Wine + Windows Python 3.11.8 Kurulumu ===
# [*] Wine: wine-11.0
# [*] Python 3.11.8 embeddable zip indiriliyor...
# /tmp/python-3.11.8- 100%[===================>]  10.69M  --.-KB/s    in 0.03s
# [*] Extract ediliyor...
# [*] _pth dosyası düzenleniyor...
# [*] pip kuruluyor...
# /tmp/get-pip.py     100%[===================>]   2.09M  --.-KB/s    in 0.009s
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting setuptools
#   Downloading setuptools-82.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Downloading wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting packaging>=24.0 (from wheel)
#   Downloading packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
# ----------------------------------------1.8/1.8 MB24.2 MB/s0:00:00
# Downloading setuptools-82.0.0-py3-none-any.whl (1.0 MB)
# ----------------------------------------1.0/1.0 MB17.2 MB/s0:00:00
# Downloading wheel-0.46.3-py3-none-any.whl (30 kB)
# Downloading packaging-26.0-py3-none-any.whl (74 kB)
# Installing collected packages: setuptools, pip, packaging, wheel
# ----------------------------------------4/4[wheel]
# Successfully installed packaging-26.0 pip-26.0.1 setuptools-82.0.0 wheel-0.46.3
#
# [*] Kontrol:
# Python 3.11.8
# pip 26.0.1 from C:\python311\Lib\site-packages\pip (python 3.11)
#
# [*] Başarılı! Şimdi './cross_build.sh install' çalıştır.

# %%
# !./cross_build.sh install
# Out:
# [*] === Kütüphaneler Kuruluyor ===
# [*] Tümü wheel olarak inecek, derleme yok.
#
# Requirement already satisfied: pip in C:\python311\Lib\site-packages (26.0.1)
# [*] Kuruluyor: pyinstaller
# Collecting pyinstaller
#   Downloading pyinstaller-6.19.0-py3-none-win_amd64.whl.metadata (8.5 kB)
# Collecting altgraph (from pyinstaller)
#   Downloading altgraph-0.17.5-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: packaging>=22.0 in C:\python311\Lib\site-packages
#  (from pyinstaller) (26.0)
# Collecting pefile>=2022.5.30 (from pyinstaller)
#   Downloading pefile-2024.8.26-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyinstaller-hooks-contrib>=2026.0 (from pyinstaller)
#   Downloading pyinstaller_hooks_contrib-2026.2-py3-none-any.whl.metadata (16 kB)
#
# Collecting pywin32-ctypes>=0.2.1 (from pyinstaller)
#   Downloading pywin32_ctypes-0.2.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: setuptools>=42.0.0 in C:\python311\Lib\site-packa
# ges (from pyinstaller) (82.0.0)
# Downloading pyinstaller-6.19.0-py3-none-win_amd64.whl (1.4 MB)
# ----------------------------------------1.4/1.4 MB26.1 MB/s0:00:00
# Downloading pefile-2024.8.26-py3-none-any.whl (74 kB)
# Downloading pyinstaller_hooks_contrib-2026.2-py3-none-any.whl (453 kB)
# Downloading pywin32_ctypes-0.2.3-py3-none-any.whl (30 kB)
# Downloading altgraph-0.17.5-py2.py3-none-any.whl (21 kB)
# Installing collected packages: altgraph, pywin32-ctypes, pyinstaller-hooks-contr
# ib, pefile, pyinstaller
# ----------------------------------------5/5[pyinstaller]
# Successfully installed altgraph-0.17.5 pefile-2024.8.26 pyinstaller-6.19.0 pyins
# taller-hooks-contrib-2026.2 pywin32-ctypes-0.2.3
#   OK
# [*] Kuruluyor: numpy
# Collecting numpy
#   Downloading numpy-2.4.2-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.2-cp311-cp311-win_amd64.whl (12.6 MB)
# ----------------------------------------12.6/12.6 MB43.2 MB/s0:00:00
# Installing collected packages: numpy
# Successfully installed numpy-2.4.2
#   OK
# [*] Kuruluyor: scipy
# Collecting scipy
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in C:\python311\Lib\site-packa
# ges (from scipy) (2.4.2)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
# ----------------------------------------36.6/36.6 MB44.8 MB/s0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.17.1
#   OK
# [*] Kuruluyor: matplotlib
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in C:\python311\Lib\site-packages (fr
# om matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in C:\python311\Lib\site-packages
#  (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
#
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# ----------------------------------------8.1/8.1 MB55.8 MB/s0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
# ----------------------------------------2.3/2.3 MB27.2 MB/s0:00:00
# Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
# ----------------------------------------7.0/7.0 MB42.0 MB/s0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, pillow, kiwisolver, fonttools, cy
# cler, contourpy, python-dateutil, matplotlib
# ----------------------------------------9/9[matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver
# -1.4.9 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2 python-dateutil-2.9.0.pos
# t0 six-1.17.0
#   OK
# [*] Kuruluyor: cvxpy
# Collecting cvxpy
#   Downloading cvxpy-1.8.1-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting osqp>=1.0.0 (from cvxpy)
#   Downloading osqp-1.1.1-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# Collecting clarabel>=0.5.0 (from cvxpy)
#   Downloading clarabel-0.11.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy)
#   Downloading scs-3.2.11-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=2.0.0 in C:\python311\Lib\site-packages (f
# rom cvxpy) (2.4.2)
# Requirement already satisfied: scipy>=1.13.0 in C:\python311\Lib\site-packages (
# from cvxpy) (1.17.1)
# Collecting highspy>=1.11.0 (from cvxpy)
#   Downloading highspy-1.13.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting cffi (from clarabel>=0.5.0->cvxpy)
#   Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# Collecting jinja2 (from osqp>=1.0.0->cvxpy)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in C:\python311\Lib\site-packages (fro
# m osqp>=1.0.0->cvxpy) (82.0.0)
# Collecting joblib (from osqp>=1.0.0->cvxpy)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting pycparser (from cffi->clarabel>=0.5.0->cvxpy)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->osqp>=1.0.0->cvxpy)
#   Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Downloading cvxpy-1.8.1-cp311-cp311-win_amd64.whl (1.3 MB)
# ----------------------------------------1.3/1.3 MB20.3 MB/s0:00:00
# Downloading clarabel-0.11.1-cp39-abi3-win_amd64.whl (887 kB)
# ----------------------------------------887.3/887.3 kB13.6 MB/s0:00:00
# Downloading highspy-1.13.1-cp311-cp311-win_amd64.whl (2.2 MB)
# ----------------------------------------2.2/2.2 MB27.4 MB/s0:00:00
# Downloading osqp-1.1.1-cp311-cp311-win_amd64.whl (310 kB)
# Downloading scs-3.2.11-cp311-cp311-win_amd64.whl (7.5 MB)
# ----------------------------------------7.5/7.5 MB38.4 MB/s0:00:00
# Downloading cffi-2.0.0-cp311-cp311-win_amd64.whl (182 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: pycparser, MarkupSafe, joblib, highspy, scs, jinj
# a2, cffi, osqp, clarabel, cvxpy
# ----------------------------------------10/10[cvxpy]
# Successfully installed MarkupSafe-3.0.3 cffi-2.0.0 clarabel-0.11.1 cvxpy-1.8.1 h
# ighspy-1.13.1 jinja2-3.1.6 joblib-1.5.3 osqp-1.1.1 pycparser-3.0 scs-3.2.11
#   OK
# [*] Kuruluyor: pygame
# Collecting pygame
#   Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Downloading pygame-2.6.1-cp311-cp311-win_amd64.whl (10.6 MB)
# ----------------------------------------10.6/10.6 MB43.7 MB/s0:00:00
# Installing collected packages: pygame
# Successfully installed pygame-2.6.1
#   OK
# [*] Kuruluyor: clarabel
# Requirement already satisfied: clarabel in C:\python311\Lib\site-packages (0.11.
# 1)
# Requirement already satisfied: numpy in C:\python311\Lib\site-packages (from cla
# rabel) (2.4.2)
# Requirement already satisfied: scipy in C:\python311\Lib\site-packages (from cla
# rabel) (1.17.1)
# Requirement already satisfied: cffi in C:\python311\Lib\site-packages (from clar
# abel) (2.0.0)
# Requirement already satisfied: pycparser in C:\python311\Lib\site-packages (from
#  cffi->clarabel) (3.0)
#   OK
# [*] Kuruluyor: pillow
# Requirement already satisfied: pillow in C:\python311\Lib\site-packages (12.1.1)
#
#   OK
#
# [*] Kurulum tamam. './cross_build.sh test' ile kontrol et.

# %%
# !./cross_build.sh test
# Out:
# [*] === Kurulum Testi ===
# Python 3.11.8 (tags/v3.11.8:db85d51, Feb  6 2024, 22:03:32) [MSC v.1937 64 bit (
# AMD64)]
# Platform: win32
#
#   numpy           2.4.2      OK
#   scipy           1.17.1     OK
#   matplotlib      3.10.8     OK
#   cvxpy           1.8.1      OK
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#   pygame          2.6.1      OK
#   clarabel        0.11.1     OK
#   PyInstaller     6.19.0     OK
#
# 7/7 modul hazir

# %%
# !./cross_build.sh build
# Out:
# [*] === Build: main.py → MyApp.exe ===
# [*] PyInstaller çalışıyor...
#
# 812 INFO: PyInstaller: 6.19.0, contrib hooks: 2026.2
# 813 INFO: Python: 3.11.8
# 878 INFO: Platform: Windows-10-10.0.19045-SP0
# 879 INFO: Python environment: C:\python311
# 882 INFO: wrote Z:\content\MyApp.spec
# 904 INFO: Removing temporary files and cleaning cache in C:\users\root\AppData\Local\pyinstaller
# 2583 INFO: generated new fontManager
# 2875 WARNING: Failed to collect submodules for 'matplotlib.tests' because importing 'matplotlib.tests' raised: OSError: The baseline image directory does not exist. This is most likely because the test data is not installed. You may need to install matplotlib from source to get the test data.
# 26775 WARNING: collect_data_files - skipping data collection for module 'ecos' as it is not a package.
# 26777 WARNING: collect_dynamic_libs - skipping library collection for module 'ecos' as it is not a package.
# 28935 INFO: Module search paths (PYTHONPATH):
# 30955 INFO: Appending 'datas' from .spec
# 32564 INFO: checking Analysis
# 32565 INFO: Building Analysis because Analysis-00.toc is non existent
# 32565 INFO: Looking for Python shared library...
# 32565 INFO: Using Python shared library: C:\python311\python311.dll
# 32565 INFO: Running Analysis Analysis-00.toc
# 32565 INFO: Target bytecode optimization level: 0
# 32565 INFO: Initializing module dependency graph...
# 32569 INFO: Initializing module graph hook caches...
# 32662 INFO: Analyzing modules for base_library.zip ...
# 36691 INFO: Processing standard module hook 'hook-heapq.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 36797 INFO: Processing standard module hook 'hook-encodings.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 39460 INFO: Processing standard module hook 'hook-pickle.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 41732 INFO: Caching module dependency graph...
# 41852 INFO: Analyzing Z:\content\main.py
# 41913 INFO: Processing standard module hook 'hook-numpy.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 44078 INFO: Processing standard module hook 'hook-difflib.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 44545 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 44874 INFO: Processing standard module hook 'hook-xml.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 45360 INFO: Processing standard module hook 'hook-_ctypes.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 46662 INFO: Processing standard module hook 'hook-sysconfig.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 46803 INFO: Processing standard module hook 'hook-platform.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 48957 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 48965 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 54708 INFO: Processing standard module hook 'hook-scipy.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 58273 INFO: Processing standard module hook 'hook-pycparser.py' from 'C:\\python311\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 58792 INFO: Processing standard module hook 'hook-setuptools.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 58848 INFO: Processing pre-safe-import-module hook 'hook-distutils.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 58851 INFO: Processing pre-find-module-path hook 'hook-distutils.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 60515 INFO: Processing standard module hook 'hook-distutils.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 60548 INFO: Processing standard module hook 'hook-distutils.util.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 60619 INFO: Processing standard module hook 'hook-_osx_support.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 60664 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61035 INFO: Processing pre-safe-import-module hook 'hook-jaraco.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61038 INFO: Setuptools: 'jaraco' appears to be a full setuptools-vendored copy - creating alias to 'setuptools._vendor.jaraco'!
# 61071 INFO: Processing standard module hook 'hook-setuptools._vendor.jaraco.text.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 61079 INFO: Processing pre-safe-import-module hook 'hook-importlib_resources.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61101 INFO: Processing pre-safe-import-module hook 'hook-backports.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61104 INFO: Setuptools: 'backports' appears to be a full setuptools-vendored copy - creating alias to 'setuptools._vendor.backports'!
# 61281 INFO: Processing pre-safe-import-module hook 'hook-more_itertools.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61284 INFO: Setuptools: 'more_itertools' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.more_itertools'!
# 61670 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 61674 INFO: Setuptools: 'importlib_metadata' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.importlib_metadata'!
# 62034 INFO: Processing standard module hook 'hook-setuptools._vendor.importlib_metadata.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 62137 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 62141 INFO: Setuptools: 'zipp' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.zipp'!
# 62828 INFO: Processing pre-safe-import-module hook 'hook-tomli.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 62832 INFO: Setuptools: 'tomli' appears to be a setuptools-vendored copy - creating alias to 'setuptools._vendor.tomli'!
# 64292 INFO: Processing pre-safe-import-module hook 'hook-wheel.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 64856 INFO: Processing standard module hook 'hook-scipy.special._ufuncs.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 66231 INFO: Processing standard module hook 'hook-scipy.linalg.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 73561 INFO: Processing standard module hook 'hook-scipy.spatial._ckdtree.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 73697 INFO: Processing standard module hook 'hook-matplotlib.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 75662 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 76186 INFO: Processing standard module hook 'hook-matplotlib.backend_bases.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 76445 INFO: Processing standard module hook 'hook-PIL.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 76619 INFO: Processing standard module hook 'hook-PIL.Image.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 78082 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 78591 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 80232 INFO: Processing standard module hook 'hook-jinja2.py' from 'C:\\python311\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 81373 INFO: Processing standard module hook 'hook-matplotlib.backends.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 81530 INFO: Processing standard module hook 'hook-matplotlib.pyplot.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 83939 INFO: Processing standard module hook 'hook-dateutil.py' from 'C:\\python311\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\stdhooks'
# 84298 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module'
# 89939 INFO: Processing standard module hook 'hook-scipy.spatial.transform.rotation.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 92209 INFO: Processing standard module hook 'hook-scipy.stats._stats.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 93410 INFO: Processing standard module hook 'hook-scipy.sparse.csgraph.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 95293 INFO: Processing standard module hook 'hook-scipy.special._ellip_harm_2.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 101433 INFO: Processing standard module hook 'hook-pygame.py' from 'C:\\python311\\Lib\\site-packages\\pygame\\__pyinstaller'
# 102895 INFO: Analyzing hidden import 'numpy.core._methods'
# 102897 ERROR: Hidden import 'numpy.core._methods' not found
# 102897 INFO: Analyzing hidden import 'numpy.core._dtype_ctypes'
# 102902 INFO: Analyzing hidden import 'matplotlib.backends.backend_tkagg'
# 102966 INFO: Processing pre-find-module-path hook 'hook-tkinter.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 102974 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 103244 WARNING: tkinter installation is broken. It will be excluded from the application
# 103271 INFO: Analyzing hidden import 'matplotlib._animation_data'
# 103274 INFO: Analyzing hidden import 'matplotlib._internal_utils'
# 103284 INFO: Analyzing hidden import 'matplotlib._type1font'
# 103347 INFO: Analyzing hidden import 'matplotlib.animation'
# 103416 INFO: Analyzing hidden import 'matplotlib.backends._backend_gtk'
# 103437 INFO: Analyzing hidden import 'matplotlib.backends._backend_pdf_ps'
# 109028 INFO: Analyzing hidden import 'matplotlib.backends.backend_cairo'
# 109074 INFO: Analyzing hidden import 'matplotlib.backends.backend_gtk3'
# 109187 INFO: Analyzing hidden import 'matplotlib.backends.backend_gtk3agg'
# 109199 INFO: Analyzing hidden import 'matplotlib.backends.backend_gtk3cairo'
# 109213 INFO: Analyzing hidden import 'matplotlib.backends.backend_gtk4'
# 109261 INFO: Analyzing hidden import 'matplotlib.backends.backend_gtk4agg'
# 109268 INFO: Analyzing hidden import 'matplotlib.backends.backend_gtk4cairo'
# 109275 INFO: Analyzing hidden import 'matplotlib.backends.backend_macosx'
# 109292 INFO: Analyzing hidden import 'matplotlib.backends.backend_mixed'
# 109298 INFO: Analyzing hidden import 'matplotlib.backends.backend_nbagg'
# 109325 INFO: Analyzing hidden import 'matplotlib.backends.backend_pdf'
# 109484 INFO: Analyzing hidden import 'matplotlib.backends.backend_pgf'
# 109548 INFO: Analyzing hidden import 'matplotlib.backends.backend_ps'
# 109653 INFO: Analyzing hidden import 'matplotlib.backends.backend_qt'
# 109764 INFO: Processing standard module hook 'hook-matplotlib.backends.qt_compat.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 111079 WARNING: hook-matplotlib.backends.qt_compat: no Qt bindings are available!
# 111146 INFO: Analyzing hidden import 'matplotlib.backends.backend_qt5'
# 111156 INFO: Analyzing hidden import 'matplotlib.backends.backend_qt5agg'
# 111169 INFO: Processing standard module hook 'hook-matplotlib.backends.backend_qtagg.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 111174 INFO: Analyzing hidden import 'matplotlib.backends.backend_qt5cairo'
# 111186 INFO: Processing standard module hook 'hook-matplotlib.backends.backend_qtcairo.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 111193 INFO: Analyzing hidden import 'matplotlib.backends.backend_svg'
# 111282 INFO: Analyzing hidden import 'matplotlib.backends.backend_template'
# 111289 INFO: Analyzing hidden import 'matplotlib.backends.backend_tkcairo'
# 111295 INFO: Analyzing hidden import 'matplotlib.backends.backend_wx'
# 111517 INFO: Analyzing hidden import 'matplotlib.backends.backend_wxagg'
# 111527 INFO: Analyzing hidden import 'matplotlib.backends.backend_wxcairo'
# 111534 INFO: Analyzing hidden import 'matplotlib.pylab'
# 111542 INFO: Analyzing hidden import 'matplotlib.sankey'
# 111622 INFO: Analyzing hidden import 'matplotlib.sphinxext'
# 111626 INFO: Analyzing hidden import 'matplotlib.sphinxext.figmpl_directive'
# 111661 INFO: Analyzing hidden import 'matplotlib.sphinxext.mathmpl'
# 111694 INFO: Analyzing hidden import 'matplotlib.sphinxext.plot_directive'
# 111768 INFO: Analyzing hidden import 'matplotlib.sphinxext.roles'
# 111782 INFO: Analyzing hidden import 'matplotlib.testing'
# 111798 INFO: Analyzing hidden import 'matplotlib.testing._markers'
# 111877 INFO: Analyzing hidden import 'matplotlib.testing.conftest'
# 111936 INFO: Analyzing hidden import 'matplotlib.testing.jpl_units'
# 112012 INFO: Analyzing hidden import 'matplotlib.testing.widgets'
# 112158 INFO: Analyzing hidden import 'cvxpy.constraints.utilities'
# 112173 INFO: Analyzing hidden import 'cvxpy.lin_ops.tree_mat'
# 113980 INFO: Analyzing hidden import 'cvxpy.problems.iterative'
# 113998 INFO: Analyzing hidden import 'cvxpy.reductions.dcp2cone.canonicalizers.mul_canon'
# 114006 INFO: Analyzing hidden import 'cvxpy.reductions.dgp2dcp.canonicalizers.nonpos_constr_canon'
# 114010 INFO: Analyzing hidden import 'cvxpy.reductions.dgp2dcp.canonicalizers.parameter_canon'
# 114019 INFO: Analyzing hidden import 'cvxpy.reductions.dgp2dcp.canonicalizers.zero_constr_canon'
# 114025 INFO: Analyzing hidden import 'cvxpy.reductions.eliminate_pwl.eliminate_pwl'
# 114039 INFO: Analyzing hidden import 'cvxpy.reductions.solvers.intermediate_chain'
# 114051 INFO: Analyzing hidden import 'cvxpy.tests'
# 114055 INFO: Analyzing hidden import 'cvxpy.tests.base_test'
# 114066 INFO: Analyzing hidden import 'cvxpy.tests.ram_limited'
# 114073 INFO: Analyzing hidden import 'cvxpy.tests.solver_test_helpers'
# 114351 INFO: Analyzing hidden import 'cvxpy.tests.test_KKT'
# 114503 INFO: Analyzing hidden import 'cvxpy.tests.test_atoms'
# 114868 INFO: Analyzing hidden import 'cvxpy.tests.test_attributes'
# 114936 INFO: Analyzing hidden import 'cvxpy.tests.test_backend_selection'
# 114969 INFO: Analyzing hidden import 'cvxpy.tests.test_base_classes'
# 114976 INFO: Analyzing hidden import 'cvxpy.tests.test_canon_sign'
# 114984 INFO: Analyzing hidden import 'cvxpy.tests.test_clarabel'
# 115002 INFO: Analyzing hidden import 'cvxpy.tests.test_coeff_extractor'
# 115081 INFO: Analyzing hidden import 'cvxpy.tests.test_complex'
# 115216 INFO: Analyzing hidden import 'cvxpy.tests.test_complex_dpp'
# 115241 INFO: Analyzing hidden import 'cvxpy.tests.test_conic_solvers'
# 115712 INFO: Analyzing hidden import 'cvxpy.tests.test_constant'
# 115729 INFO: Analyzing hidden import 'cvxpy.tests.test_constant_atoms'
# 115804 INFO: Analyzing hidden import 'cvxpy.tests.test_constraints'
# 115893 INFO: Analyzing hidden import 'cvxpy.tests.test_convolution'
# 115923 INFO: Analyzing hidden import 'cvxpy.tests.test_copt_write'
# 115930 INFO: Analyzing hidden import 'cvxpy.tests.test_copy'
# 115946 INFO: Analyzing hidden import 'cvxpy.tests.test_curvature'
# 115963 INFO: Analyzing hidden import 'cvxpy.tests.test_custom_solver'
# 115975 INFO: Analyzing hidden import 'cvxpy.tests.test_cvxpygen'
# 116008 INFO: Analyzing hidden import 'cvxpy.tests.test_derivative'
# 116087 INFO: Analyzing hidden import 'cvxpy.tests.test_dgp'
# 116122 INFO: Analyzing hidden import 'cvxpy.tests.test_dgp2dcp'
# 116209 INFO: Analyzing hidden import 'cvxpy.tests.test_dgp_dpp'
# 116221 INFO: Analyzing hidden import 'cvxpy.tests.test_domain'
# 116243 INFO: Analyzing hidden import 'cvxpy.tests.test_dpp'
# 116413 INFO: Analyzing hidden import 'cvxpy.tests.test_dqcp'
# 116487 INFO: Analyzing hidden import 'cvxpy.tests.test_einsum'
# 116511 INFO: Analyzing hidden import 'cvxpy.tests.test_errors'
# 116525 INFO: Analyzing hidden import 'cvxpy.tests.test_examples'
# 116564 INFO: Analyzing hidden import 'cvxpy.tests.test_expression_methods'
# 116599 INFO: Analyzing hidden import 'cvxpy.tests.test_expressions'
# 116768 INFO: Analyzing hidden import 'cvxpy.tests.test_grad'
# 116839 INFO: Analyzing hidden import 'cvxpy.tests.test_gurobi_write'
# 116845 INFO: Analyzing hidden import 'cvxpy.tests.test_interfaces'
# 116860 INFO: Analyzing hidden import 'cvxpy.tests.test_kron_canon'
# 116876 INFO: Analyzing hidden import 'cvxpy.tests.test_labels'
# 116905 INFO: Analyzing hidden import 'cvxpy.tests.test_lin_ops'
# 116920 INFO: Analyzing hidden import 'cvxpy.tests.test_linalg_utils'
# 116932 INFO: Analyzing hidden import 'cvxpy.tests.test_linear_cone'
# 116977 INFO: Analyzing hidden import 'cvxpy.tests.test_logic'
# 117095 INFO: Analyzing hidden import 'cvxpy.tests.test_matrices'
# 117112 INFO: Analyzing hidden import 'cvxpy.tests.test_matrix_utilities'
# 117123 INFO: Analyzing hidden import 'cvxpy.tests.test_mip_vars'
# 117144 INFO: Analyzing hidden import 'cvxpy.tests.test_monotonicity'
# 117155 INFO: Analyzing hidden import 'cvxpy.tests.test_nd_matmul'
# 117229 INFO: Analyzing hidden import 'cvxpy.tests.test_nonlinear_atoms'
# 117251 INFO: Analyzing hidden import 'cvxpy.tests.test_objectives'
# 117266 INFO: Analyzing hidden import 'cvxpy.tests.test_param_cone_prog'
# 117283 INFO: Analyzing hidden import 'cvxpy.tests.test_param_quad_prog'
# 117303 INFO: Analyzing hidden import 'cvxpy.tests.test_perspective'
# 117343 INFO: Analyzing hidden import 'cvxpy.tests.test_pow_cone_nd'
# 117376 INFO: Analyzing hidden import 'cvxpy.tests.test_power_atom'
# 117415 INFO: Analyzing hidden import 'cvxpy.tests.test_power_tools'
# 117429 INFO: Analyzing hidden import 'cvxpy.tests.test_problem'
# 117679 INFO: Analyzing hidden import 'cvxpy.tests.test_python_backends'
# 117937 INFO: Analyzing hidden import 'cvxpy.tests.test_qp_solvers'
# 118041 INFO: Analyzing hidden import 'cvxpy.tests.test_quad_form'
# 118064 INFO: Analyzing hidden import 'cvxpy.tests.test_quadratic'
# 118087 INFO: Analyzing hidden import 'cvxpy.tests.test_quantum_rel_entr'
# 118106 INFO: Analyzing hidden import 'cvxpy.tests.test_scalarize'
# 118125 INFO: Analyzing hidden import 'cvxpy.tests.test_semidefinite_vars'
# 118138 INFO: Analyzing hidden import 'cvxpy.tests.test_shape'
# 118151 INFO: Analyzing hidden import 'cvxpy.tests.test_sign'
# 118161 INFO: Analyzing hidden import 'cvxpy.tests.test_soc_dim3'
# 118185 INFO: Analyzing hidden import 'cvxpy.tests.test_solver_data_validation'
# 118194 INFO: Analyzing hidden import 'cvxpy.tests.test_solver_inverse_data'
# 118200 INFO: Analyzing hidden import 'cvxpy.tests.test_suppfunc'
# 118221 INFO: Analyzing hidden import 'cvxpy.tests.test_valinvec2mixedint'
# 118276 INFO: Analyzing hidden import 'cvxpy.tests.test_versioning'
# 118285 INFO: Analyzing hidden import 'cvxpy.tests.test_von_neumann_entr'
# 118310 INFO: Analyzing hidden import 'cvxpy.utilities.cvxpy_upgrade'
# 118318 INFO: Processing module hooks (post-graph stage)...
# 118337 WARNING: Hidden import "pycparser.lextab" not found!
# 118338 WARNING: Hidden import "pycparser.yacctab" not found!
# 118351 INFO: Processing standard module hook 'hook-matplotlib.backends.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 118354 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 120371 INFO: Found configured default matplotlib backend: agg
# 120371 INFO: Selected matplotlib backends: ['agg']
# 121086 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 121242 WARNING: Hidden import "scipy.special._cdflib" not found!
# 122369 INFO: Performing binary vs. data reclassification (1137 entries)
# 124739 INFO: Looking for ctypes DLLs
# 125707 INFO: Analyzing run-time hooks ...
# 125735 INFO: Including run-time hook 'pyi_rth_inspect.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 125747 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 125764 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 125775 INFO: Including run-time hook 'pyi_rth_setuptools.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 125785 INFO: Including run-time hook 'pyi_rth_mplconfig.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks'
# 125793 INFO: Processing pre-find-module-path hook 'hook-_pyi_rth_utils.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path'
# 125802 INFO: Processing standard module hook 'hook-_pyi_rth_utils.py' from 'C:\\python311\\Lib\\site-packages\\PyInstaller\\hooks'
# 126054 INFO: Creating base_library.zip...
# 126141 INFO: Looking for dynamic libraries
# 142625 INFO: Extra DLL search directories (AddDllDirectory): ['C:\\python311\\Lib\\site-packages\\numpy.libs', 'C:\\python311\\Lib\\site-packages\\scipy.libs', 'C:\\python311\\Lib\\site-packages\\scs.libs', 'C:\\python311\\Lib\\site-packages\\pygame']
# 142626 INFO: Extra DLL search directories (PATH): []
# 145930 WARNING: Excluding Wine built-in DLL: C:\windows\system32\MSVCP140.dll
# 158388 INFO: Warnings written to Z:\content\build\MyApp\warn-MyApp.txt
# 159182 INFO: Graph cross-reference written to Z:\content\build\MyApp\xref-MyApp.html
# 159402 INFO: checking PYZ
# 159402 INFO: Building PYZ because PYZ-00.toc is non existent
# 159402 INFO: Building PYZ (ZlibArchive) Z:\content\build\MyApp\PYZ-00.pyz
# 163377 INFO: Building PYZ (ZlibArchive) Z:\content\build\MyApp\PYZ-00.pyz completed successfully.
# 163505 INFO: checking PKG
# 163506 INFO: Building PKG because PKG-00.toc is non existent
# 163506 INFO: Building PKG (CArchive) MyApp.pkg
# 217373 INFO: Building PKG (CArchive) MyApp.pkg completed successfully.
# 217421 INFO: Bootloader C:\python311\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\runw.exe
# 217421 INFO: checking EXE
# 217421 INFO: Building EXE because EXE-00.toc is non existent
# 217421 INFO: Building EXE from EXE-00.toc
# 217423 INFO: Copying bootloader EXE to Z:\content\dist\MyApp.exe
# 217438 INFO: Copying icon to EXE
# 217453 INFO: Copying 0 resources to EXE
# 217453 INFO: Embedding manifest in EXE
# 217461 INFO: Appending PKG archive to EXE
# 217655 INFO: Fixing EXE headers
# 218786 INFO: Building EXE from EXE-00.toc completed successfully.
# 218866 INFO: Build complete! The results are available in: Z:\content\dist
#
# ══════════════════════════════════════════
#   BUILD BAŞARILI!
#   EXE:   /content/dist/MyApp.exe
#   Boyut: 91M
#   Hedef: Windows 10 x64
# ══════════════════════════════════════════

# %%
from google.colab import files
files.download('dist/MyApp.exe')

# %%
# !cat > ~/.wine/drive_c/python311/Lib/site-packages/sitecustomize.py << 'EOF'
import os
os.environ['MPLBACKEND'] = 'agg'
EOF
# Out:
# /bin/bash: line 1: warning: here-document at line 1 delimited by end-of-file (wanted `EOF')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_403/407525023.py in <cell line: 0>()
#       2 import os
#       3 os.environ['MPLBACKEND'] = 'agg'
# ----> 4 EOF
#
# NameError: name 'EOF' is not defined

# %%
# !wine ~/.wine/drive_c/python311/python.exe -c "import os ; print(os.environ.get('MPLBACKEND'))"

# !wine ~/.wine/drive_c/python311/python.exe -c "import matplotlib ; print('hello world')"
# Out:
# error: XDG_RUNTIME_DIR not set in the environment.
# 0050:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 0050:err:winediag:nodrv_CreateWindow L"The explorer process failed to start."
# 0050:err:systray:initialize_systray Could not create tray window
# 00c0:err:ntoskrnl:ZwLoadDriver failed to create driver L"\\Registry\\Machine\\System\\CurrentControlSet\\Services\\winebth": c00000e5
# 003c:fixme:service:scmdatabase_autostart_services Auto-start service L"winebth" failed to start: 1359
# hello world

# %%
# !sudo dpkg --add-architecture i386

# %%
# !sudo mkdir -pm755 /etc/apt/keyrings

# %%
# !sudo wget -O /etc/apt/keyrings/winehq-archive.key https://dl.winehq.org/wine-builds/winehq.key
# Out:
# --2026-03-09 06:32:49--  https://dl.winehq.org/wine-builds/winehq.key
# Resolving dl.winehq.org (dl.winehq.org)... 151.101.2.217, 151.101.66.217, 151.101.130.217, ...
# Connecting to dl.winehq.org (dl.winehq.org)|151.101.2.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3212 (3.1K) [application/pgp-keys]
# Saving to: ‘/etc/apt/keyrings/winehq-archive.key’
#
# /etc/apt/keyrings/w 100%[===================>]   3.14K  --.-KB/s    in 0s
#
# 2026-03-09 06:32:49 (40.6 MB/s) - ‘/etc/apt/keyrings/winehq-archive.key’ saved [3212/3212]

# %%
! sudo wget -NP /etc/apt/sources.list.d/ https://dl.winehq.org/wine-builds/ubuntu/dists/jammy/winehq-jammy.sources
# Out:
# --2026-03-09 06:39:04--  https://dl.winehq.org/wine-builds/ubuntu/dists/jammy/winehq-jammy.sources
# Resolving dl.winehq.org (dl.winehq.org)... 151.101.2.217, 151.101.66.217, 151.101.130.217, ...
# Connecting to dl.winehq.org (dl.winehq.org)|151.101.2.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 163 [binary/octet-stream]
# Saving to: ‘/etc/apt/sources.list.d/winehq-jammy.sources’
#
# winehq-jammy.source 100%[===================>]     163  --.-KB/s    in 0s
#
# 2026-03-09 06:39:04 (2.57 MB/s) - ‘/etc/apt/sources.list.d/winehq-jammy.sources’ saved [163/163]

# %%
# !sudo apt update
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:3 https://dl.winehq.org/wine-builds/ubuntu jammy InRelease [8,909 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:7 https://dl.winehq.org/wine-builds/ubuntu jammy/main i386 Packages [444 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:11 https://dl.winehq.org/wine-builds/ubuntu jammy/main amd64 Packages [447 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Fetched 1,283 kB in 2s (574 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 81 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !sudo apt install --install-recommends winehq-stable
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   acl avahi-daemon ipp-usb libavahi-core7 libcurl3-gnutls libcurl3-gnutls:i386
#   libdaemon0 libgdbm-compat4:i386 libgdbm6:i386 libglu1-mesa libglu1-mesa:i386
#   libieee1284-3 libieee1284-3:i386 libnspr4:i386 libnss-mdns libnss3
#   libnss3:i386 libopengl0:i386 libopenjp2-7:i386 libpci3 libpci3:i386
#   libperl5.34:i386 libpoppler-glib8 libpoppler-glib8:i386 libpoppler118:i386
#   libsane-common libsane1 libsane1:i386 libsnmp-base libsnmp40 libsnmp40:i386
#   libwrap0:i386 libxkbregistry0 libxkbregistry0:i386 pci.ids poppler-data
#   sane-airscan sane-utils systemd-hwe-hwdb udev update-inetd wine-stable
#   wine-stable-amd64 wine-stable-i386:i386
# Suggested packages:
#   avahi-autoipd gdbm-l10n:i386 avahi-autoipd | zeroconf hplip hplip:i386
#   snmp-mibs-downloader poppler-utils ghostscript fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum unpaper
# Recommended packages:
#   sane-airscan:i386
# The following packages will be REMOVED:
#   wine
# The following NEW packages will be installed:
#   acl avahi-daemon ipp-usb libavahi-core7 libcurl3-gnutls:i386 libdaemon0
#   libgdbm-compat4:i386 libgdbm6:i386 libglu1-mesa libglu1-mesa:i386
#   libieee1284-3 libieee1284-3:i386 libnspr4:i386 libnss-mdns libnss3:i386
#   libopengl0:i386 libopenjp2-7:i386 libpci3 libpci3:i386 libperl5.34:i386
#   libpoppler-glib8 libpoppler-glib8:i386 libpoppler118:i386 libsane-common
#   libsane1 libsane1:i386 libsnmp-base libsnmp40 libsnmp40:i386 libwrap0:i386
#   libxkbregistry0 libxkbregistry0:i386 pci.ids poppler-data sane-airscan
#   sane-utils systemd-hwe-hwdb udev update-inetd wine-stable wine-stable-amd64
#   wine-stable-i386:i386 winehq-stable
# The following packages will be upgraded:
#   libcurl3-gnutls libnss3
# 2 upgraded, 43 newly installed, 1 to remove and 79 not upgraded.
# Need to get 269 MB of archives.
# After this operation, 1,665 MB of additional disk space will be used.
# Get:1 https://dl.winehq.org/wine-builds/ubuntu jammy/main i386 wine-stable-i386 i386 11.0.0.0~jammy-1 [117 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-core7 amd64 0.8-5ubuntu5.4 [90.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdaemon0 amd64 0.14-7.1ubuntu3 [14.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 avahi-daemon amd64 0.8-5ubuntu5.4 [69.7 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsane-common all 1.1.1-5 [915 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 update-inetd all 4.51 [24.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libieee1284-3 amd64 0.2.11-14build2 [22.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 acl amd64 2.3.1-1 [38.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 udev amd64 249.11-0ubuntu3.17 [1,557 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcurl3-gnutls amd64 7.81.0-1ubuntu1.22 [284 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpoppler-glib8 amd64 22.02.0-2ubuntu0.12 [134 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsnmp-base all 5.9.1+dfsg-1ubuntu2.9 [201 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsnmp40 amd64 5.9.1+dfsg-1ubuntu2.9 [1,070 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsane1 amd64 1.1.1-5 [2,763 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 sane-utils amd64 1.1.1-5 [198 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libcurl3-gnutls i386 7.81.0-1ubuntu1.22 [313 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main i386 libieee1284-3 i386 0.2.11-14build2 [24.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libnspr4 i386 2:4.35-0ubuntu0.22.04.1 [129 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnss3 amd64 2:3.98-0ubuntu0.22.04.3 [1,347 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libnss3 i386 2:3.98-0ubuntu0.22.04.3 [1,475 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libopenjp2-7 i386 2.4.0-6ubuntu0.4 [172 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libpoppler118 i386 22.02.0-2ubuntu0.12 [1,154 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libpoppler-glib8 i386 22.02.0-2ubuntu0.12 [147 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main i386 libpci3 i386 1:3.7.0-6 [30.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main i386 libgdbm6 i386 1.23-1 [39.9 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main i386 libgdbm-compat4 i386 1.23-1 [7,144 B]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libperl5.34 i386 5.34.0-3ubuntu1.5 [4,381 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main i386 libwrap0 i386 7.6.q-31build2 [48.8 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main i386 libsnmp40 i386 5.9.1+dfsg-1ubuntu2.9 [1,098 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main i386 libsane1 i386 1.1.1-5 [2,791 kB]
# Get:34 https://dl.winehq.org/wine-builds/ubuntu jammy/main amd64 wine-stable-amd64 amd64 11.0.0.0~jammy-1 [124 MB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main i386 libxkbregistry0 i386 1.4.0-1 [15.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbregistry0 amd64 1.4.0-1 [14.1 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ipp-usb amd64 0.9.20-1ubuntu0.22.04.2 [2,023 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnss-mdns amd64 0.15.1-1ubuntu1 [27.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 sane-airscan amd64 0.99.27-1build1 [140 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-hwe-hwdb all 249.11.6 [3,668 B]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main i386 libopengl0 i386 1.4.0-1 [35.4 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main i386 libglu1-mesa i386 9.0.2-1 [199 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglu1-mesa amd64 9.0.2-1 [145 kB]
# Get:44 https://dl.winehq.org/wine-builds/ubuntu jammy/main amd64 wine-stable amd64 11.0.0.0~jammy-1 [2,960 kB]
# Get:45 https://dl.winehq.org/wine-builds/ubuntu jammy/main amd64 winehq-stable amd64 11.0.0.0~jammy-1 [1,340 B]
# Fetched 269 MB in 7s (38.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 45.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 121784 files and directories currently installed.)
# Removing wine (6.0.3~repack-1) ...
# Selecting previously unselected package libavahi-core7:amd64.
# (Reading database ... 121740 files and directories currently installed.)
# Preparing to unpack .../00-libavahi-core7_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking libavahi-core7:amd64 (0.8-5ubuntu5.4) ...
# Selecting previously unselected package libdaemon0:amd64.
# Preparing to unpack .../01-libdaemon0_0.14-7.1ubuntu3_amd64.deb ...
# Unpacking libdaemon0:amd64 (0.14-7.1ubuntu3) ...
# Selecting previously unselected package avahi-daemon.
# Preparing to unpack .../02-avahi-daemon_0.8-5ubuntu5.4_amd64.deb ...
# Unpacking avahi-daemon (0.8-5ubuntu5.4) ...
# Selecting previously unselected package libsane-common.
# Preparing to unpack .../03-libsane-common_1.1.1-5_all.deb ...
# Unpacking libsane-common (1.1.1-5) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../04-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package update-inetd.
# Preparing to unpack .../05-update-inetd_4.51_all.deb ...
# Unpacking update-inetd (4.51) ...
# Selecting previously unselected package libieee1284-3:amd64.
# Preparing to unpack .../06-libieee1284-3_0.2.11-14build2_amd64.deb ...
# Unpacking libieee1284-3:amd64 (0.2.11-14build2) ...
# Selecting previously unselected package acl.
# Preparing to unpack .../07-acl_2.3.1-1_amd64.deb ...
# Unpacking acl (2.3.1-1) ...
# Selecting previously unselected package udev.
# Preparing to unpack .../08-udev_249.11-0ubuntu3.17_amd64.deb ...
# Unpacking udev (249.11-0ubuntu3.17) ...
# Preparing to unpack .../09-libcurl3-gnutls_7.81.0-1ubuntu1.22_amd64.deb ...
# Unpacking libcurl3-gnutls:amd64 (7.81.0-1ubuntu1.22) over (7.81.0-1ubuntu1.21) ...
# Selecting previously unselected package libpoppler-glib8:amd64.
# Preparing to unpack .../10-libpoppler-glib8_22.02.0-2ubuntu0.12_amd64.deb ...
# Unpacking libpoppler-glib8:amd64 (22.02.0-2ubuntu0.12) ...
# Selecting previously unselected package pci.ids.
# Preparing to unpack .../11-pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../12-libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package libsnmp-base.
# Preparing to unpack .../13-libsnmp-base_5.9.1+dfsg-1ubuntu2.9_all.deb ...
# Unpacking libsnmp-base (5.9.1+dfsg-1ubuntu2.9) ...
# Selecting previously unselected package libsnmp40:amd64.
# Preparing to unpack .../14-libsnmp40_5.9.1+dfsg-1ubuntu2.9_amd64.deb ...
# Unpacking libsnmp40:amd64 (5.9.1+dfsg-1ubuntu2.9) ...
# Selecting previously unselected package libsane1:amd64.
# Preparing to unpack .../15-libsane1_1.1.1-5_amd64.deb ...
# Unpacking libsane1:amd64 (1.1.1-5) ...
# Selecting previously unselected package sane-utils.
# Preparing to unpack .../16-sane-utils_1.1.1-5_amd64.deb ...
# Unpacking sane-utils (1.1.1-5) ...
# Selecting previously unselected package libcurl3-gnutls:i386.
# Preparing to unpack .../17-libcurl3-gnutls_7.81.0-1ubuntu1.22_i386.deb ...
# Unpacking libcurl3-gnutls:i386 (7.81.0-1ubuntu1.22) ...
# Selecting previously unselected package libieee1284-3:i386.
# Preparing to unpack .../18-libieee1284-3_0.2.11-14build2_i386.deb ...
# Unpacking libieee1284-3:i386 (0.2.11-14build2) ...
# Selecting previously unselected package libnspr4:i386.
# Preparing to unpack .../19-libnspr4_2%3a4.35-0ubuntu0.22.04.1_i386.deb ...
# Unpacking libnspr4:i386 (2:4.35-0ubuntu0.22.04.1) ...
# Preparing to unpack .../20-libnss3_2%3a3.98-0ubuntu0.22.04.3_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.98-0ubuntu0.22.04.3) over (2:3.98-0ubuntu0.22.04.2) ...
# Selecting previously unselected package libnss3:i386.
# Preparing to unpack .../21-libnss3_2%3a3.98-0ubuntu0.22.04.3_i386.deb ...
# Unpacking libnss3:i386 (2:3.98-0ubuntu0.22.04.3) ...
# Selecting previously unselected package libopenjp2-7:i386.
# Preparing to unpack .../22-libopenjp2-7_2.4.0-6ubuntu0.4_i386.deb ...
# Unpacking libopenjp2-7:i386 (2.4.0-6ubuntu0.4) ...
# Selecting previously unselected package libpoppler118:i386.
# Preparing to unpack .../23-libpoppler118_22.02.0-2ubuntu0.12_i386.deb ...
# Unpacking libpoppler118:i386 (22.02.0-2ubuntu0.12) ...
# Selecting previously unselected package libpoppler-glib8:i386.
# Preparing to unpack .../24-libpoppler-glib8_22.02.0-2ubuntu0.12_i386.deb ...
# Unpacking libpoppler-glib8:i386 (22.02.0-2ubuntu0.12) ...
# Selecting previously unselected package libpci3:i386.
# Preparing to unpack .../25-libpci3_1%3a3.7.0-6_i386.deb ...
# Unpacking libpci3:i386 (1:3.7.0-6) ...
# Selecting previously unselected package libgdbm6:i386.
# Preparing to unpack .../26-libgdbm6_1.23-1_i386.deb ...
# Unpacking libgdbm6:i386 (1.23-1) ...
# Selecting previously unselected package libgdbm-compat4:i386.
# Preparing to unpack .../27-libgdbm-compat4_1.23-1_i386.deb ...
# Unpacking libgdbm-compat4:i386 (1.23-1) ...
# Selecting previously unselected package libperl5.34:i386.
# Preparing to unpack .../28-libperl5.34_5.34.0-3ubuntu1.5_i386.deb ...
# Unpacking libperl5.34:i386 (5.34.0-3ubuntu1.5) ...
# Selecting previously unselected package libwrap0:i386.
# Preparing to unpack .../29-libwrap0_7.6.q-31build2_i386.deb ...
# Unpacking libwrap0:i386 (7.6.q-31build2) ...
# Selecting previously unselected package libsnmp40:i386.
# Preparing to unpack .../30-libsnmp40_5.9.1+dfsg-1ubuntu2.9_i386.deb ...
# Unpacking libsnmp40:i386 (5.9.1+dfsg-1ubuntu2.9) ...
# Selecting previously unselected package libsane1:i386.
# Preparing to unpack .../31-libsane1_1.1.1-5_i386.deb ...
# Unpacking libsane1:i386 (1.1.1-5) ...
# Selecting previously unselected package libxkbregistry0:i386.
# Preparing to unpack .../32-libxkbregistry0_1.4.0-1_i386.deb ...
# Unpacking libxkbregistry0:i386 (1.4.0-1) ...
# Selecting previously unselected package wine-stable-i386:i386.
# Preparing to unpack .../33-wine-stable-i386_11.0.0.0~jammy-1_i386.deb ...
# Unpacking wine-stable-i386:i386 (11.0.0.0~jammy-1) ...
# Selecting previously unselected package libxkbregistry0:amd64.
# Preparing to unpack .../34-libxkbregistry0_1.4.0-1_amd64.deb ...
# Unpacking libxkbregistry0:amd64 (1.4.0-1) ...
# Selecting previously unselected package wine-stable-amd64.
# Preparing to unpack .../35-wine-stable-amd64_11.0.0.0~jammy-1_amd64.deb ...
# Unpacking wine-stable-amd64 (11.0.0.0~jammy-1) ...
# Selecting previously unselected package wine-stable.
# Preparing to unpack .../36-wine-stable_11.0.0.0~jammy-1_amd64.deb ...
# Unpacking wine-stable (11.0.0.0~jammy-1) ...
# Selecting previously unselected package ipp-usb.
# Preparing to unpack .../37-ipp-usb_0.9.20-1ubuntu0.22.04.2_amd64.deb ...
# Unpacking ipp-usb (0.9.20-1ubuntu0.22.04.2) ...
# Selecting previously unselected package libnss-mdns:amd64.
# Preparing to unpack .../38-libnss-mdns_0.15.1-1ubuntu1_amd64.deb ...
# Unpacking libnss-mdns:amd64 (0.15.1-1ubuntu1) ...
# Selecting previously unselected package sane-airscan.
# Preparing to unpack .../39-sane-airscan_0.99.27-1build1_amd64.deb ...
# Unpacking sane-airscan (0.99.27-1build1) ...
# Selecting previously unselected package systemd-hwe-hwdb.
# Preparing to unpack .../40-systemd-hwe-hwdb_249.11.6_all.deb ...
# Unpacking systemd-hwe-hwdb (249.11.6) ...
# Selecting previously unselected package winehq-stable.
# Preparing to unpack .../41-winehq-stable_11.0.0.0~jammy-1_amd64.deb ...
# Unpacking winehq-stable (11.0.0.0~jammy-1) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../42-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libopengl0:i386.
# Preparing to unpack .../43-libopengl0_1.4.0-1_i386.deb ...
# Unpacking libopengl0:i386 (1.4.0-1) ...
# Selecting previously unselected package libglu1-mesa:i386.
# Preparing to unpack .../44-libglu1-mesa_9.0.2-1_i386.deb ...
# Unpacking libglu1-mesa:i386 (9.0.2-1) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up libpoppler-glib8:amd64 (22.02.0-2ubuntu0.12) ...
# Setting up sane-airscan (0.99.27-1build1) ...
# Setting up libsnmp-base (5.9.1+dfsg-1ubuntu2.9) ...
# Setting up update-inetd (4.51) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libcurl3-gnutls:amd64 (7.81.0-1ubuntu1.22) ...
# Setting up libcurl3-gnutls:i386 (7.81.0-1ubuntu1.22) ...
# Setting up libnss3:amd64 (2:3.98-0ubuntu0.22.04.3) ...
# Setting up libopengl0:i386 (1.4.0-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up acl (2.3.1-1) ...
# Setting up libwrap0:i386 (7.6.q-31build2) ...
# Setting up libxkbregistry0:amd64 (1.4.0-1) ...
# Setting up libxkbregistry0:i386 (1.4.0-1) ...
# Setting up libnspr4:i386 (2:4.35-0ubuntu0.22.04.1) ...
# Setting up udev (249.11-0ubuntu3.17) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up systemd-hwe-hwdb (249.11.6) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up libpci3:i386 (1:3.7.0-6) ...
# Setting up libopenjp2-7:i386 (2.4.0-6ubuntu0.4) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libglu1-mesa:i386 (9.0.2-1) ...
# Setting up libsane-common (1.1.1-5) ...
# Setting up libieee1284-3:amd64 (0.2.11-14build2) ...
# Setting up libieee1284-3:i386 (0.2.11-14build2) ...
# Setting up libdaemon0:amd64 (0.14-7.1ubuntu3) ...
# Setting up libavahi-core7:amd64 (0.8-5ubuntu5.4) ...
# Setting up libnss-mdns:amd64 (0.15.1-1ubuntu1) ...
# First installation detected...
# Checking NSS setup...
# Setting up libgdbm6:i386 (1.23-1) ...
# Setting up libnss3:i386 (2:3.98-0ubuntu0.22.04.3) ...
# Setting up libpoppler118:i386 (22.02.0-2ubuntu0.12) ...
# Setting up libsnmp40:amd64 (5.9.1+dfsg-1ubuntu2.9) ...
# Setting up libgdbm-compat4:i386 (1.23-1) ...
# Setting up avahi-daemon (0.8-5ubuntu5.4) ...
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of force-reload.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Created symlink /etc/systemd/system/dbus-org.freedesktop.Avahi.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/avahi-daemon.service → /lib/systemd/system/avahi-daemon.service.
# Created symlink /etc/systemd/system/sockets.target.wants/avahi-daemon.socket → /lib/systemd/system/avahi-daemon.socket.
# Setting up ipp-usb (0.9.20-1ubuntu0.22.04.2) ...
# Setting up libperl5.34:i386 (5.34.0-3ubuntu1.5) ...
# Setting up libpoppler-glib8:i386 (22.02.0-2ubuntu0.12) ...
# Setting up libsane1:amd64 (1.1.1-5) ...
# Adding scanner group...
# Setting up wine-stable-amd64 (11.0.0.0~jammy-1) ...
# Setting up libsnmp40:i386 (5.9.1+dfsg-1ubuntu2.9) ...
# Setting up sane-utils (1.1.1-5) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# update-inetd: warning: cannot add service, /etc/inetd.conf does not exist
# Adding saned group and user...
# Adding user saned to group scanner
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libsane1:i386 (1.1.1-5) ...
# Setting up wine-stable-i386:i386 (11.0.0.0~jammy-1) ...
# Setting up wine-stable (11.0.0.0~jammy-1) ...
# Setting up winehq-stable (11.0.0.0~jammy-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for dbus (1.12.20-2ubuntu4.1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link

# %%
# !wineboot --init
# Out:
# wine: created the configuration directory '/root/.wine'
# 002c:fixme:actctx:parse_depend_manifests Could not find dependent assembly L"Microsoft.Windows.Common-Controls" (6.0.0.0)
# 004c:fixme:actctx:parse_depend_manifests Could not find dependent assembly L"Microsoft.Windows.Common-Controls" (6.0.0.0)
# 0054:fixme:actctx:parse_depend_manifests Could not find dependent assembly L"Microsoft.Windows.Common-Controls" (6.0.0.0)
# error: XDG_RUNTIME_DIR not set in the environment.
# error: XDG_RUNTIME_DIR not set in the environment.
# 004c:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 004c:err:winediag:nodrv_CreateWindow L"The explorer process failed to start."
# 004c:err:systray:initialize_systray Could not create tray window
# 004c:err:ole:StdMarshalImpl_MarshalInterface Failed to create ifstub, hr 0x80004002
# 004c:err:ole:CoMarshalInterface Failed to marshal the interface {6d5140c1-7436-11ce-8034-00aa006009fa}, hr 0x80004002
# 004c:err:ole:apartment_get_local_server_stream Failed: 0x80004002
# 002c:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 002c:err:winediag:nodrv_CreateWindow L"Make sure that your display server is running and that its variables are set."
# 0054:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 0054:err:winediag:nodrv_CreateWindow L"Make sure that your display server is running and that its variables are set."
# 0054:err:ole:apartment_createwindowifneeded CreateWindow failed with error 3
# 0054:err:ole:apartment_createwindowifneeded CreateWindow failed with error 0
# 0054:err:ole:apartment_createwindowifneeded CreateWindow failed with error 14007
# 0054:err:ole:StdMarshalImpl_MarshalInterface Failed to create ifstub, hr 0x800736b7
# 0054:err:ole:CoMarshalInterface Failed to marshal the interface {6d5140c1-7436-11ce-8034-00aa006009fa}, hr 0x800736b7
# 0054:err:ole:apartment_get_local_server_stream Failed: 0x800736b7
# 0054:err:ole:start_rpcss Failed to open RpcSs service
# 0044:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 0044:err:winediag:nodrv_CreateWindow L"Make sure that your display server is running and that its variables are set."
# 0098:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 0098:err:winediag:nodrv_CreateWindow L"Make sure that your display server is running and that its variables are set."
# 00a0:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 00a0:err:winediag:nodrv_CreateWindow L"Make sure that your display server is running and that its variables are set."
# 00ec:err:winediag:nodrv_CreateWindow Application tried to create a window, but no driver could be loaded.
# 00ec:err:winediag:nodrv_CreateWindow L"Make sure that your display server is running and that its variables are set."
# 002c:err:setupapi:do_file_copyW Unsupported style(s) 0x10
# 0110:err:ntoskrnl:ZwLoadDriver failed to create driver L"\\Registry\\Machine\\System\\CurrentControlSet\\Services\\winebth": c00000e5
# 002c:err:setupapi:SetupDiInstallDevice Failed to start service L"winebth" for device L"ROOT\\WINE\\WINEBTH", error 1359.
# 002c:err:setupapi:SetupDiInstallDevice Failed to control service L"winebth" for device L"ROOT\\WINE\\WINEBTH", error 1062.
# 002c:err:setupapi:do_file_copyW Unsupported style(s) 0x10
# 0138:err:setupapi:do_file_copyW Unsupported style(s) 0x10
# 002c:err:setupapi:do_file_copyW Unsupported style(s) 0x10
# 0138:err:setupapi:do_file_copyW Unsupported style(s) 0x10
# 004c:err:ole:start_rpcss Failed to start RpcSs service
# 0188:err:rpc:I_RpcReceive we got fault packet with status 0x1c010003
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"MountMgr" failed to start: 1053
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"PlugPlay" failed to start: 1115
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"Eventlog" failed to start: 1115
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"nsiproxy" failed to start: 1115
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"NDIS" failed to start: 1115
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"winebus" failed to start: 1115
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"wineusb" failed to start: 1115
# 017c:fixme:service:scmdatabase_autostart_services Auto-start service L"winebth" failed to start: 1115
