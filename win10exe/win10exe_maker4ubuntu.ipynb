# %%
# !git clone https://github.com/DemirDorukDilek/DDoP --branch Util --single-branch git
# !mv git/run.py ./main.py
# !mv git/DDOP .

# %% [markdown]
# apt index ve update

# %%
# !sudo dpkg --add-architecture i386

# %%
# !sudo mkdir -pm755 /etc/apt/keyrings

# %%
# !sudo wget -O /etc/apt/keyrings/winehq-archive.key https://dl.winehq.org/wine-builds/winehq.key

# %%
! sudo wget -NP /etc/apt/sources.list.d/ https://dl.winehq.org/wine-builds/ubuntu/dists/jammy/winehq-jammy.sources

# %%
# !sudo apt update

# %%
# !sudo apt install --install-recommends winehq-stable

# %%
# !wineboot --init

# %% [markdown]
# deppendency donwload

# %%
# !chmod +x cross_build.sh

# %%
# !./cross_build.sh  setup

# %%
# !./cross_build.sh install

# %% [markdown]
# fix backend

# %%
# !cat > ~/.wine/drive_c/python311/Lib/site-packages/sitecustomize.py << 'EOF'
import os
os.environ['MPLBACKEND'] = 'agg'
EOF

# %%
# !./cross_build.sh test

# %% [markdown]
# build

# %%
# !./cross_build.sh build
# Out:
# [*] === Build: main.py → MyApp.exe ===
# [*] PyInstaller çalışıyor...
#
# 627 INFO: PyInstaller: 6.19.0, contrib hooks: 2026.3
# 627 INFO: Python: 3.11.8
# 688 INFO: Platform: Windows-10-10.0.19045-SP0
# 688 INFO: Python environment: C:\python311
# 691 INFO: wrote Z:\content\MyApp.spec
# 701 INFO: Removing temporary files and cleaning cache in C:\users\root\AppData\Local\pyinstaller
# 1688 WARNING: Failed to collect submodules for 'matplotlib.tests' because importing 'matplotlib.tests' raised: OSError: The baseline image directory does not exist. This is most likely because the test data is not installed. You may need to install matplotlib from source to get the test data.
# 19066 WARNING: collect_data_files - skipping data collection for module 'ecos' as it is not a package.
# 19067 WARNING: collect_dynamic_libs - skipping library collection for module 'ecos' as it is not a package.
# 20698 INFO: Module search paths (PYTHONPATH):
# 22018 INFO: Appending 'datas' from .spec
# ...

# %%
from google.colab import files
files.download('dist/MyApp.exe')

# %%
# !rm main.py
# !rm -rf DDOP
# !rm -rf git
# !git clone https://github.com/DemirDorukDilek/DDoP --branch Util --single-branch git
# !mv git/run.py ./main.py
# !mv git/DDOP .
# Out:
# Cloning into 'git'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 198 (delta 52), reused 35 (delta 18), pack-reused 100 (from 1)
# Receiving objects: 100% (198/198), 3.32 MiB | 13.12 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
# !rm main.py
# !rm -rf DDOP
# !rm -rf git
# !git clone https://github.com/DemirDorukDilek/DDoP --branch Util --single-branch git
# !mv git/run.py ./main.py
# !mv git/DDOP .
# !./cross_build.sh build
from google.colab import files
files.download('dist/MyApp.exe')
# Out:
# Cloning into 'git'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 203 (delta 56), reused 35 (delta 18), pack-reused 100 (from 1)
# Receiving objects: 100% (203/203), 3.32 MiB | 13.49 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# [*] === Build: main.py → MyApp.exe ===
# [*] PyInstaller çalışıyor...
#
# 557 INFO: PyInstaller: 6.19.0, contrib hooks: 2026.3
# 558 INFO: Python: 3.11.8
# 610 INFO: Platform: Windows-10-10.0.19045-SP0
# 610 INFO: Python environment: C:\python311
# 612 INFO: wrote Z:\content\MyApp.spec
# 622 INFO: Removing temporary files and cleaning cache in C:\users\root\AppData\Local\pyinstaller
# ...
